# %% [markdown]
# <a href="https://colab.research.google.com/github/WaltherBarrientos/machine_learning/blob/master/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's start on the basics. Variables and arrays

# %% [markdown]
# ### First, import some libraries

# %%
#Importaciones
import numpy as np

# %%
array_1 = np.array([8,7,5,9,2,10]) # Create an array of 6 values
print (type(array_1), array_1.dtype)
# Out:
# <class 'numpy.ndarray'> int64

# %%
array_2 = np.array(np.random.randint(0,10,len(array_1))) # Create an array of random int values
                                                      # with the same lenght as array_1

print (array_1, array_2) # print both array_1 and array_2
print (array_1.shape, array_2.shape) # print both array_1 and array_2 shapes
print (array_1 + array_2) # print summation of array_1 and array_2
# Out:
# [ 8  7  5  9  2 10] [0 0 5 4 4 8]
# (6,) (6,)
# [ 8  7 10 13  6 18]

# %%
array_1[3] = 70 # Replace the value of array_1 in pos 3 by 70
print (array_1 + array_2) # Print summation again
# Out:
# [ 8  7 10 74  6 18]

# %%
# array_1[1] = 32 # Replace the values of array_1 in pos 1-3 by 32
# array_1[2] = 32
# array_1[3] = 32
array_1[1:3] = 32
print (array_1 + array_2) # Print summation again
# Out:
# [ 8 32 37 74  6 18]

# %%
array_3 = array_1 * array_2 # Apply element-wise multiplication among array_1 and array_2
# [ 8 32 32 32  2 10] [5 5 5 3 7 4]
array_4 = np.dot(array_1, array_2)
print (array_3, array_4)# Print results
# Out:
# [  0   0 160 280   8  80] 528

# %% [markdown]
# # Playing with some images! Introduction to OpenCV
#
# Download the image [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view) before getting started!

# %% [markdown]
# ### First, let's mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import some libraries

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load an image using OpenCV

# %%
# Loading a color image
img = cv2.imread( "/content/Lena.png" )
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img) # plots an image

# %% [markdown]
# ### Let's play with the data

# %%
print (type(img), img.dtype)
print (img.shape)
# Out:
# <class 'numpy.ndarray'> uint8
# (439, 440, 3)

# %%
# Printing the image shape (size of the image)
print (img.shape)
# Out:
# (439, 440, 3)

# %%
# Looking through the image...
# print among image indexes
print (img[0:10,5:15,0])
# Out:
# [[197 197 197 192 192 188 188 188 178 188]
#  [197 192 197 192 192 188 192 183 178 183]
#  [192 197 197 192 188 188 188 183 178 178]
#  [192 192 197 192 188 192 192 188 178 188]
#  [192 192 192 192 192 183 192 192 183 188]
#  [192 192 197 192 183 192 192 188 183 188]
#  [192 192 188 183 183 183 183 188 183 178]
#  [192 192 183 192 188 183 192 183 188 183]
#  [192 192 192 183 192 188 188 192 188 178]
#  [192 183 183 183 183 183 183 183 183 183]]

# %%
# Changing its channels values!
img = cv2.imread( "/content/Lena.png" )
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img[0:100, 100:200, 0:2] = 255
plt.imshow(img) # Voila!

# %% [markdown]
# ### Load an image in grayscale

# %%
# Loading a color image in grayscale
img_gray = cv2.imread( "/content/Lena.png", 0)
plt.imshow(img_gray, cmap="gray")

# %% [markdown]
# ### Play with the image

# %%
# Printing the image shape
print (img_gray.shape)
# Out:
# (439, 440)

# %%
# Regarding through the image... Again
print (img_gray[0:10, 10:20])
# Out:
# [[133 133 133 127 133 131 127 124 120 112]
#  [133 139 131 127 131 127 124 124 120 109]
#  [133 133 131 127 127 127 124 124 120 109]
#  [139 139 133 127 133 127 124 120 120 112]
#  [131 139 139 131 133 131 124 120 120 115]
#  [139 139 133 131 133 127 120 120 120 112]
#  [131 131 133 131 127 127 127 127 124 115]
#  [131 139 131 133 131 124 133 120 120 118]
#  [133 133 139 133 127 120 131 120 120 115]
#  [131 131 131 131 131 120 131 115 120 112]]

# %% [markdown]
# ### Going further

# %%
cv2.imwrite('newlena.png',img_gray)
# Out:
# True

# %% [markdown]
# ### Crop the image - taking regions of interest (ROI)

# %%
# Extract some ROI
roi = _
plt.imshow(roi, _ )

# %%
img_gray[ _ , _ ] = roi
plt.imshow(img_gray, _ )

# %% [markdown]
# ## Load an image using pillow (PIL)

# %%
from PIL import Image

# %%
# Loading a color image
img = Image.open( "/content/Lena.png" )
plt.imshow(img) # plots an image

# %%
#img = np.asarray( img ) ## Convert to an array
img = np.array( img )

# %%
print (type(img), img.dtype)
# Out:
# <class 'numpy.ndarray'> uint8

# %%
print (img[:10, :10]) ## Error. This is not an array
# Out:
# [[ 60  60  60  60 135 135 135 135  60  60]
#  [ 60 135  60 135  60 135  60 135  60  60]
#  [135  60 135  60 135  60 135 135  60  72]
#  [135 135 135 135  60  60  60 135  60  72]
#  [135 135  60 135  60  60  60  60  60  60]
#  [135  60 135 135  60  60  60 135  60 136]
#  [ 60  35  60  60  60  60  60  72 136 136]
#  [ 60  60  60  60  60  60  60 136  60  72]
#  [ 60  55  60  60  60  60  60  60 136  60]
#  [ 60  60  60  60  60  60 136 136 136 136]]

# %%
# Abre la imagen en escala de grises utilizando PIL
img = Image.open("/content/Lena.png").convert("L")

# Muestra la imagen en escala de grises utilizando Matplotlib
plt.imshow(img, cmap='gray')
plt.show()

# Obtiene y muestra la forma (dimensiones) de la imagen utilizando NumPy
img_array = np.array(img)
print(img_array.shape)
# Out:
# (439, 440)

# %% [markdown]
# ### Load the image in grayscale
